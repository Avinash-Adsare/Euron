# %%
pip install nltk spacy emoji contractions
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached spacy-3.8.7-cp313-cp313-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 7.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/13.9 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.7/13.9 MB 8.6 MB/s eta 0:00:02
#    ------------- -------------------------- 4.7/13.9 MB 7.3 MB/s eta 0:00:02
#    --------------- ------------------------ 5.5/13.9 MB 6.5 MB/s eta 0:00:02
#    ------------------ --------------------- 6.3/13.9 MB 5.9 MB/s eta 0:00:02
#    -------------------- ------------------- 7.1/13.9 MB 5.6 MB/s eta 0:00:02
# ...

# %%
text = "🚀 ## Become a Job-Ready Product Manager in Just 4 Months."

# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import re,string,nltk,spacy,emoji,contractions
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,SnowballStemmer ## Stemmer - convert to base word
from nltk.tokenize import word_tokenize,sent_tokenize
from spacy.lang.en.stop_words import STOP_WORDS as spacy_stopwords

# %%
text
type(text)
# Out:
# str

# %%
text = text.lower()

# %%
text = "🚀  become a job-ready #product #manager in just 4 months,let's, isn't."

# %%
text = contractions.fix(text)

# %%
text
# Out:
# '🚀  become a job-ready #product #manager in just 4 months,let us, is not.'

# %%
text = emoji.replace_emoji(text,replace='')

# %%
text
# Out:
# '  become a job-ready #product #manager in just 4 months,let us, is not.'

# %%
## remove hashtag by regular expression
text = re.sub(r"#\w+","",text)

# %%
text
# Out:
# '  become a job-ready   in just 4 months,let us, is not.'

# %%
text = text.translate(str.maketrans("","",string.punctuation))

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sent_tokenize(text)
# Out:
# ['  become a jobready   in just 4 monthslet us is not']

# %%
text = 'become a job ready.   in just 4 monthslet us is not'
sent_tokenize(text=text)
# Out:
# ['become a job ready.', 'in just 4 monthslet us is not']

# %%
word =word_tokenize(text)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopwords.words()
# Out:
# ['tyre',
#  'rreth',
#  'le',
#  'atyre',
#  'këta',
#  'megjithëse',
#  'kemi',
#  'per',
#  'ndonëse',
#  'dytë',
#  'pse',
#  'tha',
#  'aty',
#  'ndaj',
#  'ke',
#  'këtë',
#  'duhet',
#  'pa',
#  'perket',
#  'veç',
#  'ndonje',
#  'një',
#  'keshtu',
#  's',
#  'janë',
#  'jane',
#  'ti',
#  'ia',
#  'megjithese',
#  'prej',
#  'ishte',
#  'tjerë',
#  'ai',
#  'se',
#  'tillë',
#  'do',
#  'si',
#  'ja',
#  'tonë',
#  'keta',
#  'pastaj',
#  'ndersa',
#  'siç',
#  'unë',
#  'gjate',
#  'di',
#  'kësaj',
#  'cilin',
#  'kjo',
#  'dhënë',
#  'da',
#  'teper',
#  'ketij',
#  'ama',
#  'pasi',
#  'fjalë',
#  'kanë',
#  'vetem',
#  'za',
#  'd.m.th.',
#  'ose',
#  'pas',
#  'ndonjë',
#  'cila',
#  'ndodhur',
#  'dyte',
#  'ardhur',
#  'kësi',
#  'nga',
#  'vete',
#  'atij',
#  'ta',
#  'jenë',
#  'rendit',
#  'tane',
#  'keso',
#  'deri',
#  'tone',
#  'të',
#  'prandaj',
#  'bëjë',
#  'domethënë',
#  'dhe',
#  'qi',
#  'mirepo',
#  'tona',
#  'që',
#  'u',
#  'këtu',
#  'cilet',
# ...

# %%
'the' in stopwords.words()
# Out:
# True

# %%
len(stopwords.words())
# Out:
# 11009

# %%
word
# Out:
# ['become',
#  'a',
#  'job',
#  'ready',
#  '.',
#  'in',
#  'just',
#  '4',
#  'monthslet',
#  'us',
#  'is',
#  'not']

# %%
[w for w in word if w not in stopwords.words()]
# Out:
# ['job', 'ready', '.', '4', 'monthslet']

# %%
text
# Out:
# 'become a job ready.   in just 4 monthslet us is not'

# %%
cleaned = re.sub(r"\s+","",text) ## space remove

# %%
cleaned
# Out:
# 'becomeajobready.injust4monthsletusisnot'

# %%
## digit remove
cleaned =re.sub(r"\d+","",cleaned)

# %%
## steaming

data= word_tokenize(cleaned)

# %%
data
# Out:
# ['becomeajobready.injustmonthsletusisnot']

# %%
strmer = PorterStemmer()

# %%
strmer.stem("learning")
# Out:
# 'learn'

# %%
for i in data:
    print(strmer.stem(i))
# Out:
# becomeajobready.injustmonthsletusisnot

# %%
snow = SnowballStemmer('english')

# %%
snow.stem("learning")
# Out:
# 'learn'

# %%
for i in data:
    print(snow.stem(i))
# Out:
# becomeajobready.injustmonthsletusisnot

# %%
# lemitization - little bit differenet from stammer

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---- ----------------------------------- 1.6/12.8 MB 12.4 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.4/12.8 MB 14.8 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.5/12.8 MB 11.1 MB/s eta 0:00:01
#      ------------------- -------------------- 6.3/12.8 MB 9.1 MB/s eta 0:00:01
#      --------------------- ------------------ 6.8/12.8 MB 7.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.3/12.8 MB 6.0 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.6/12.8 MB 5.5 MB/s eta 0:00:01
#      ------------------------- -------------- 8.1/12.8 MB 4.9 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 4.6 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.8 MB 4.3 MB/s eta 0:00:01
# ...

# %%
spacy.load("en_core_web_sm")

# %%
text
# Out:
# 'become a job ready.   in just 4 monthslet us is not'

# %%
type(data)
# Out:
# list
